# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# Ensure all columns are displayed
pd.set_option('display.max_columns', None)

# If rows are also getting truncated, you can use:
pd.set_option('display.max_rows', None)

# If the output is still too wide, you can adjust the column width:
pd.set_option('display.width', 1000)

# If columns are getting cut off, set column width to unlimited:
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('..\data\processed_data\merged_data.csv')

# %%
df2 = df.copy()

# %%
df.head()
# Out:
#    SalesKey  OrderKey  ProductKey  CustomerKey CustomerType  Quantity_x  TotalAmount   OrderDate  IsHighValueOrder  OrderYear  OrderMonth  OrderDay  OrderId  StoreId  CustomerId_x CustomerIp  OrderStatusId           CreatedOnUtc_x  OrderSubTotalExclTax  OrderSubTotalInclTax  OrderTotal  OrderItemId  ProductId_x  Quantity_y  UnitPriceInclTax  UnitPriceExclTax  IsPickupInstore  CustomerId_y FirstName LastName                        Email PostalCode  RegisteredStoreId CreatedOnUtc_y LastActivityDateUtc  IsDeleted  ProductId_y  LocationId                        ProductName        Category  CategoryId  Price        SKU
# 0         1         2          14            1    Returning           1       1855.0  2020-01-11              True       2020           1        11        1        1             4  127.0.0.1             20  2020-01-11 22:46:10.093                1855.0                1855.0      1855.0            2           16           1             530.0             530.0            False             4     Steve    Gates  steve_gates@nopCommerce.com      90077                  1     2020-01-11          2020-03-01       True           16           0  Leica T Mirrorless Digital Camera  Camera & photo           6  530.0  LT_MIR_DC
# 1         2         2          14            6    Returning           1       1855.0  2020-01-11              True       2020           1        11        1        1             4  127.0.0.1             20  2020-01-11 22:46:10.093                1855.0                1855.0      1855.0            2           16           1             530.0             530.0            False             4     Steve    Gates  steve_gates@nopCommerce.com      92118                  1     2020-01-11          2020-03-01       True           16           0  Leica T Mirrorless Digital Camera  Camera & photo           6  530.0  LT_MIR_DC
# 2         3         2          14            7    Returning           1       1855.0  2020-01-11              True       2020           1        11        1        1             4  127.0.0.1             20  2020-01-11 22:46:10.093                1855.0                1855.0      1855.0            2           16           1             530.0             530.0            False             4     Steve    Gates  steve_gates@nopCommerce.com      51739                  1     2020-01-11          2020-03-01       True           16           0  Leica T Mirrorless Digital Camera  Camera & photo           6  530.0  LT_MIR_DC
# 3         4         2          14         2884    Returning           1       1855.0  2020-01-11              True       2020           1        11        1        1             4  127.0.0.1             20  2020-01-11 22:46:10.093                1855.0                1855.0      1855.0            2           16           1             530.0             530.0            False             4     Steve    Gates  steve_gates@nopCommerce.com      90077                  1     2020-01-11          2020-03-01       True           16           0  Leica T Mirrorless Digital Camera  Camera & photo           6  530.0  LT_MIR_DC
# 4         5         2          14         5773    Returning           1       1855.0  2020-01-11              True       2020           1        11        1        1             4  127.0.0.1             20  2020-01-11 22:46:10.093                1855.0                1855.0      1855.0            2           16           1             530.0             530.0            False             4     Steve    Gates  steve_gates@nopCommerce.com      51739                  1     2020-01-11          2020-03-01       True           16           0  Leica T Mirrorless Digital Camera  Camera & photo           6  530.0  LT_MIR_DC

# %%
df.drop(['SalesKey','OrderKey','ProductKey','CustomerKey'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   CustomerType  Quantity_x  TotalAmount   OrderDate  IsHighValueOrder  OrderYear  OrderMonth  OrderDay  OrderId  StoreId  CustomerId_x CustomerIp  OrderStatusId           CreatedOnUtc_x  OrderSubTotalExclTax  OrderSubTotalInclTax  OrderTotal  OrderItemId  ProductId_x  Quantity_y  UnitPriceInclTax  UnitPriceExclTax  IsPickupInstore  CustomerId_y FirstName LastName                        Email PostalCode  RegisteredStoreId CreatedOnUtc_y LastActivityDateUtc  IsDeleted  ProductId_y  LocationId                        ProductName        Category  CategoryId  Price        SKU
# 0    Returning           1       1855.0  2020-01-11              True       2020           1        11        1        1             4  127.0.0.1             20  2020-01-11 22:46:10.093                1855.0                1855.0      1855.0            2           16           1             530.0             530.0            False             4     Steve    Gates  steve_gates@nopCommerce.com      90077                  1     2020-01-11          2020-03-01       True           16           0  Leica T Mirrorless Digital Camera  Camera & photo           6  530.0  LT_MIR_DC
# 1    Returning           1       1855.0  2020-01-11              True       2020           1        11        1        1             4  127.0.0.1             20  2020-01-11 22:46:10.093                1855.0                1855.0      1855.0            2           16           1             530.0             530.0            False             4     Steve    Gates  steve_gates@nopCommerce.com      92118                  1     2020-01-11          2020-03-01       True           16           0  Leica T Mirrorless Digital Camera  Camera & photo           6  530.0  LT_MIR_DC
# 2    Returning           1       1855.0  2020-01-11              True       2020           1        11        1        1             4  127.0.0.1             20  2020-01-11 22:46:10.093                1855.0                1855.0      1855.0            2           16           1             530.0             530.0            False             4     Steve    Gates  steve_gates@nopCommerce.com      51739                  1     2020-01-11          2020-03-01       True           16           0  Leica T Mirrorless Digital Camera  Camera & photo           6  530.0  LT_MIR_DC
# 3    Returning           1       1855.0  2020-01-11              True       2020           1        11        1        1             4  127.0.0.1             20  2020-01-11 22:46:10.093                1855.0                1855.0      1855.0            2           16           1             530.0             530.0            False             4     Steve    Gates  steve_gates@nopCommerce.com      90077                  1     2020-01-11          2020-03-01       True           16           0  Leica T Mirrorless Digital Camera  Camera & photo           6  530.0  LT_MIR_DC
# 4    Returning           1       1855.0  2020-01-11              True       2020           1        11        1        1             4  127.0.0.1             20  2020-01-11 22:46:10.093                1855.0                1855.0      1855.0            2           16           1             530.0             530.0            False             4     Steve    Gates  steve_gates@nopCommerce.com      51739                  1     2020-01-11          2020-03-01       True           16           0  Leica T Mirrorless Digital Camera  Camera & photo           6  530.0  LT_MIR_DC

# %%
df1 = df[~df['CustomerIp'].isin(['127.0.0.1', '192.168.0.1'])]

# %%
df1.head()
# Out:
#     CustomerType  Quantity_x  TotalAmount   OrderDate  IsHighValueOrder  OrderYear  OrderMonth  OrderDay  OrderId  StoreId  CustomerId_x     CustomerIp  OrderStatusId           CreatedOnUtc_x  OrderSubTotalExclTax  OrderSubTotalInclTax  OrderTotal  OrderItemId  ProductId_x  Quantity_y  UnitPriceInclTax  UnitPriceExclTax  IsPickupInstore  CustomerId_y FirstName LastName                      Email PostalCode  RegisteredStoreId CreatedOnUtc_y LastActivityDateUtc  IsDeleted  ProductId_y  LocationId          ProductName            Category  CategoryId  Price               SKU
# 567    Returning           2        48.68  2020-08-27             False       2020           8        27       86        4          5222  99.255.123.73             40  2020-08-27 08:20:08.313                 40.97                 43.69       48.68          361           81           2              6.31              6.31            False          5222   iSnapup   Canada  isnapup@spyderscience.com    L9A 1A1                  4     2020-06-21          2025-01-07      False           81          10  HANDI CRYSTAL SUGAR  BAKING INGREDIENTS         494   6.31  CAGR-00002-00024
# 569    Returning           2        48.68  2020-08-27             False       2020           8        27       86        4          5222  99.255.123.73             40  2020-08-27 08:20:08.313                 40.97                 43.69       48.68          361           81           2              6.31              6.31            False          5222  Waterloo   region                 abc@def.ca    N2L 0C6                  4     2020-06-21          2025-01-07      False           81          10  HANDI CRYSTAL SUGAR  BAKING INGREDIENTS         494   6.31  CAGR-00002-00024
# 570    Returning           2        48.68  2020-08-27             False       2020           8        27       86        4          5222  99.255.123.73             40  2020-08-27 08:20:08.313                 40.97                 43.69       48.68          361           81           2              6.31              6.31            False          5222  Waterloo   region                 abc@def.ca    N2L 0C6                  4     2020-06-21          2025-01-07      False           81          10  HANDI CRYSTAL SUGAR  BAKING INGREDIENTS         494   6.31  CAGR-00002-00024
# 571    Returning           2        48.68  2020-08-27             False       2020           8        27       86        4          5222  99.255.123.73             40  2020-08-27 08:20:08.313                 40.97                 43.69       48.68          361           81           2              6.31              6.31            False          5222   iSnapup   Canada  isnapup@spyderscience.com    N1R 5h6                  4     2020-06-21          2025-01-07      False           81          10  HANDI CRYSTAL SUGAR  BAKING INGREDIENTS         494   6.31  CAGR-00002-00024

# %%
# Let us write a function that will help us create boxplots and histograms for any input numerical 
# variables.
# This function takes the numerical column as the input and returns the boxplots and histograms for the variable.
# This will also help us write faster and cleaner code.
def histogram_boxplot(data, xlabel = None, title = None, font_scale=2, figsize=(15,7), bins = None):
    """ Boxplot and histogram combined
    data: 1-d data array
    xlabel: xlabel 
    title: title
    font_scale: the scale of the font (default 2)
    figsize: size of fig (default (9,8))
    bins: number of bins (default None / auto)

    
    """
    mean = np.mean(data)

    sns.set(font_scale = font_scale) # setting the font scale of the seaborn
    f2, (ax_box2, ax_hist2) = plt.subplots(2, sharex = True, gridspec_kw = {"height_ratios": (.25, .75)}, figsize = figsize) # creating the 2 subplot
    sns.boxplot(x = data, ax = ax_box2, showmeans = True, color = "violet") # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(x = data, kde = False, ax = ax_hist2, bins = bins, palette="winter") if bins else sns.histplot(x = data, kde = False, ax = ax_hist2, color = "lightblue") # histogram will be made
    ax_hist2.axvline(mean, color = 'g', linestyle = '--') # mean will shown as vertical line in the histogram
    if xlabel: ax_hist2.set(xlabel = xlabel) # xlabel
    if title: ax_box2.set(title = title) # title of the graph
    plt.show() # display the graph

# Function to create barplots that indicate percentage for each category.

def perc_on_bar(plot, feature):
    '''
    plot
    feature: categorical feature
    the function won't work if a column is passed in hue parameter
    '''
    total = len(feature) # length of the column
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total) # percentage of each class of the category
        x = p.get_x() + p.get_width() / 2 - 0.05 # width of the plot
        y = p.get_y() + p.get_height() + 0.5         # height of the plot
        ax.annotate(percentage, (x, y), size = 18) # annotate the percentage 
    plt.show() # show the plot

# %%
plt.figure(figsize=(16,8))
ax = sns.countplot(x = df1["Quantity_x"],palette='winter')
perc_on_bar(ax,df1["Quantity_x"])
# Out:
# C:\Users\posta\AppData\Local\Temp\ipykernel_21668\1440837341.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x = df1["Quantity_x"],palette='winter')

# %% [markdown]
# ### 80% products are ordered with Quantity 1

# %%
histogram_boxplot(df1["TotalAmount"])
